# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data =pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['ouput']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['ouput']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['ouput']=[0,1,1,0]

# %%
sns.scatterplot(x='input1', y='input2', hue='ouput', data=and_data, s=200)
plt.show()

# %%
from sklearn.linear_model import Perceptron
c1f1=Perceptron()
c1f2=Perceptron()
c1f3=Perceptron()

# %%
c1f1.fit(and_data.iloc[:,0:2].values, and_data.iloc[:,-1].values)
c1f2.fit(or_data.iloc[:,0:2].values, and_data.iloc[:,-1].values)
c1f3.fit(xor_data.iloc[:,0:2].values, and_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
c1f1.coef_
# Out:
# array([[2., 2.]])

# %%
c1f1.intercept_
# Out:
# array([-1.])

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(x='input1', y='input2', hue='ouput', data=and_data, s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
c1f2.coef_
# Out:
# array([[2., 2.]])

# %%
c1f2.intercept_
# Out:
# array([-1.])

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(x='input1', y='input2', hue='ouput', data=or_data, s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
c1f3.coef_
# Out:
# array([[2., 2.]])

# %%
c1f3.intercept_
# Out:
# array([-1.])

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_decision_regions(X, y, clf, legend=2):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.8)

    plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.5)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.legend(loc='upper right')
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_decision_regions(X, y, clf, legend=2):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.8)

    plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.5)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.legend(loc='upper right')
    plt.show()

# %%
plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=c1f3, legend=2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
c1f3.coef_
# Out:
# array([[2., 2.]])

# %%
c1f3.intercept_
# Out:
# array([-1.])

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(x='input1', y='input2', hue='ouput', data=xor_data, s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>
