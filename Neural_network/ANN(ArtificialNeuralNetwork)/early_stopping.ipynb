# %%
import tensorflow as tf
import numpy as np 
import pandas as pd 
from pylab import rcParams 
import matplotlib.pyplot as plt 
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state =1 )

# %%
sns.scatterplot(x=X[:,0],y=X[:,1],hue=y)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=2)

# %%
model =Sequential()
model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\jroun\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer ='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs= 2000, verbose=0)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='train')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model , legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
# <Axes: >

# %%
#this is keras model and early stoping syntax is

# %%
model =Sequential()
model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer ='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
monitor="val_loss",
min_delta =0.001,
patience=10,
verbose=1,
mode="auto",
baseline=None,
restore_best_weights=True
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3500, callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7891 - loss: 0.5616 - val_accuracy: 0.6000 - val_loss: 0.6655
# Epoch 2/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8008 - loss: 0.5574 - val_accuracy: 0.6000 - val_loss: 0.6642
# Epoch 3/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8266 - loss: 0.5591 - val_accuracy: 0.6000 - val_loss: 0.6621
# Epoch 4/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7898 - loss: 0.5657 - val_accuracy: 0.6000 - val_loss: 0.6602
# Epoch 5/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8289 - loss: 0.5617 - val_accuracy: 0.6000 - val_loss: 0.6588
# Epoch 6/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8211 - loss: 0.5583 - val_accuracy: 0.6000 - val_loss: 0.6585
# Epoch 7/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8305 - loss: 0.5508 - val_accuracy: 0.6500 - val_loss: 0.6586
# Epoch 8/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8359 - loss: 0.5373 - val_accuracy: 0.6500 - val_loss: 0.6592
# Epoch 9/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8203 - loss: 0.5454 - val_accuracy: 0.7000 - val_loss: 0.6589
# Epoch 10/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8203 - loss: 0.5410 - val_accuracy: 0.7000 - val_loss: 0.6555
# Epoch 11/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8305 - loss: 0.5432 - val_accuracy: 0.7000 - val_loss: 0.6537
# Epoch 12/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8148 - loss: 0.5493 - val_accuracy: 0.7000 - val_loss: 0.6525
# Epoch 13/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8547 - loss: 0.5415 - val_accuracy: 0.7000 - val_loss: 0.6527
# Epoch 14/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8211 - loss: 0.5481 - val_accuracy: 0.7000 - val_loss: 0.6526
# Epoch 15/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8188 - loss: 0.5379 - val_accuracy: 0.7000 - val_loss: 0.6528
# Epoch 16/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8266 - loss: 0.5401 - val_accuracy: 0.7000 - val_loss: 0.6533
# Epoch 17/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8227 - loss: 0.5368 - val_accuracy: 0.7000 - val_loss: 0.6546
# Epoch 18/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8398 - loss: 0.5330 - val_accuracy: 0.6500 - val_loss: 0.6546
# Epoch 19/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8109 - loss: 0.5419 - val_accuracy: 0.6000 - val_loss: 0.6528
# Epoch 20/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8367 - loss: 0.5412 - val_accuracy: 0.6000 - val_loss: 0.6513
# Epoch 21/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8484 - loss: 0.5295 - val_accuracy: 0.6500 - val_loss: 0.6521
# Epoch 22/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8250 - loss: 0.5317 - val_accuracy: 0.7000 - val_loss: 0.6513
# Epoch 23/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8172 - loss: 0.5461 - val_accuracy: 0.7000 - val_loss: 0.6508
# Epoch 24/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8211 - loss: 0.5454 - val_accuracy: 0.6500 - val_loss: 0.6479
# Epoch 25/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8352 - loss: 0.5363 - val_accuracy: 0.7000 - val_loss: 0.6470
# Epoch 26/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8266 - loss: 0.5297 - val_accuracy: 0.7000 - val_loss: 0.6473
# Epoch 27/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8148 - loss: 0.5385 - val_accuracy: 0.6500 - val_loss: 0.6471
# Epoch 28/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8445 - loss: 0.5280 - val_accuracy: 0.6000 - val_loss: 0.6478
# Epoch 29/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8406 - loss: 0.5240 - val_accuracy: 0.6000 - val_loss: 0.6493
# Epoch 30/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8344 - loss: 0.5174 - val_accuracy: 0.6000 - val_loss: 0.6498
# Epoch 31/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8055 - loss: 0.5327 - val_accuracy: 0.6000 - val_loss: 0.6488
# Epoch 32/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8328 - loss: 0.5211 - val_accuracy: 0.6000 - val_loss: 0.6509
# Epoch 33/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8445 - loss: 0.5164 - val_accuracy: 0.6000 - val_loss: 0.6506
# Epoch 34/3500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8523 - loss: 0.5214 - val_accuracy: 0.6000 - val_loss: 0.6480
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
